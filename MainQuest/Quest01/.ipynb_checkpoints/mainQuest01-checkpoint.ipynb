# %% [markdown]
# # GPT 구현
#
# GPT는 기존의 transformer 모델과 다르게 decoder만 사용하여 학습합니다. 이는, 이전 transformer 모델과 큰 차이점이 있습니다.
#
# 1. GPT는 transformer와 학습 방법이 다릅니다. 기존의 tansformer 모델은 teach forching을 사용하여 표현을 학습할 수 있었습니다. 하지만, 이러한 방식은 labe data가 필요하고 task 별로 일반화 성능이 좋지 않을 수 있습니다.
#
# 2. GPT는 decoder 만 사용하여 다음 단어를 예측합니다. 즉, 기존의 encoder-decoder attention은 없으며 input으로 들어온 데이터에 대하여 다음단어를 예측하는 구조로 학습합니다. 이러한 방식은 unsupervised learning이 가능한 구조로 label이 없는 데이터에 대하여 학습할 수 있습니다.
#
# 3. GPT는 positional encoding을 계산하여 사용하지 않고 embedding layer를 통하여 학습하여 사용합니다. 이는 모델이 학습할 수 있는 parameter로 positional encoding을 구하는 embedding layer를 학습하여 사람이 학습하는 것 보다 더욱 좋은 결과를 가져올 수 있습니다.
#
# 4. GPT의 학습과정은 pretrain 과정과 supervised fine-tuinning으로 이루어진 semi-supervised learning에 속합니다. 즉, supervised fine-tuinning 때 task 별로 특징들을 학습하여 다음 단어를 예측하고 일반화 성능을 달성합니다.
#
# 5. GPT는 추론 시 다음 단어를 예측하는 방식으로 추론합니다. 또한 supervised fine-tuinning의 경우 FFN을 통과하여 task에 맞는 downstream 작업을 할 수 있습니다.
#
# 이번 코드에서 전처리는 바꾸지 않았고 dataset에서 처리할 때 Q와 A를 <sep> token을 사용해서 합친 후 전달하도록 하고 추론 부분에서 <sep> 이후의 단어를 예측하도록 했습니다.
#
# 아래 구조에서 바뀐 부분은 GPT) 로 검색하실 수 있습니다.

# %%
#!pip install sentencepiece

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader, random_split
import torch.optim as optim
import torch.optim.lr_scheduler as lr_scheduler
import sentencepiece as spm

import math
import os
import re
import urllib.request
import zipfile
import copy
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
path_to_dataset = os.path.join(os.getenv('HOME'), "work/transformer_chatbot/data")
path_to_chatbot = os.path.join(path_to_dataset, 'ChatbotData.csv')

data = pd.read_csv(path_to_chatbot)
data.sample(10)
# Out:
#                         Q                         A  label
# 69    강아지 키우고 싶은데 역시 안돼겠지          먼저 생활패턴을 살펴 보세요.      0
# 2167           분위기 좋았는데 망          서로를 향한 감정도 좋았겠죠.      0
# 1096   늦어지고 있는데 변명이 생각 안나          핑계보다 솔직하게 말해보세요.      0
# 8723       헤어짐이 꿈이었으면 좋겠어          현실을 직시할 필요도 있어요.      1
# 2405            생각할 수 있어?  당신이 행복하길 바라는 생각을 하고 있어요.      0
# 434         꽃다발 말리면 에쁘겠지.     거꾸로 해서 드라이플라워 만들어보세요.      0
# 2858        아무도 모르게 있고 싶어                저 나가면 될까요?      0
# 3177      여친 데려다 주고 막차 놓침                   난감하겠어요.      0
# 6999             어찌해야 될까?                어찌하면 좋을까요.      1
# 3277         오늘 길 많이 막히더라          길은 항상 막히는 것 같아요.      0

# %%
#데이터 분석 함수
#===============================================================================================================================#
def below_threshold_len(max_len, data, features):
    max_len_list = []
    # 두 입력의 길이가 맞지 않다면 맞춰주기
    if len(max_len) < len(features):
        max_len_list = [max_len for _ in range(len(features) - len(max_len))]
    elif len(max_len) > len(features):
        max_len_list = max_len[:len(features)]
    else:
        max_len_list = max_len
    
    for idx, feature in enumerate(features):
        cnt=0
        for s in data[feature]:
            if(len(s.split())<=max_len_list[idx]):
                cnt = cnt+1
        print('전체 %s 샘플 중 길이가 %s 이하인 샘플의 비율: %s'%(feature ,max_len_list[idx], (cnt / len(data[feature]))))

#데이터 길이 시각화 함수
def DataLengthVisualization(data, features, bins=40):
    
    #가변 길이 처리하기위한 dictionary
    container = dict()

    for idx, feature in enumerate(features):
        container[feature] = [len(s.split()) for s in data[feature]]
    
        print('{}의 최소 길이 : {}'.format(feature, np.min(container[feature])))
        print('{}의 최대 길이 : {}'.format(feature, np.max(container[feature])))
        print('{}의 평균 길이 : {}'.format(feature, np.mean(container[feature])))
    
        plt.subplot(1,len(features),idx+1)
        plt.boxplot(container[feature])
        plt.title(feature)
        
    plt.tight_layout()
    plt.show()

    for idx, feature in enumerate(features):
    
        plt.title(feature)
        plt.hist(container[feature],bins=bins)
        plt.xlabel('length of samples')
        plt.ylabel('number of samples')
        plt.show()

#희귀 단어 파악
def spase_word(data, features, threshold=7):

    #가변 길이 처리하기위한 dictionary
    container = dict()
    
    for feature in features:
        container[feature] = data[feature].tolist()
        
        # 단어 빈도수 계산
        word_counter = Counter()
        for text in container[feature]:
            word_counter.update(text.split())
        
        total_cnt = len(word_counter)  # 전체 단어 개수
        total_freq = sum(word_counter.values())  # 전체 단어 등장 횟수
        rare_cnt = sum(1 for count in word_counter.values() if count < threshold)  # 희귀 단어 개수
        rare_freq = sum(count for count in word_counter.values() if count < threshold)  # 희귀 단어 등장 횟수
        
        # 희귀 단어를 제외한 단어 사전 구축
        vocab = {"<PAD>": 0, "<UNK>": 1}  # 패딩 및 미등록 단어 추가
        word_index = {word: idx + 2 for idx, (word, count) in enumerate(word_counter.items()) if count >= threshold}

        print('대상 feature : ', feature)
        print('단어 집합(vocabulary)의 크기 :', total_cnt)
        print('등장 빈도가 %s번 이하인 희귀 단어의 수: %s'%(threshold - 1, rare_cnt))
        print('단어 집합에서 희귀 단어를 제외시킬 경우의 단어 집합의 크기 %s'%(total_cnt - rare_cnt))
        print("단어 집합에서 희귀 단어의 비율:", (rare_cnt / total_cnt)*100)
        print("전체 등장 빈도에서 희귀 단어 등장 빈도 비율:", (rare_freq / total_freq)*100)
        print("=======================================================================")

# %%
# 데이터 전처리
#==========================================================================================================================================================================
def preprocess_sentence(sentence):
    # 입력받은 sentence를 소문자로 변경하고 양쪽 공백을 제거
    sentence = sentence.lower().strip()

    # 단어와 구두점(punctuation) 사이의 거리를 만듭니다.
    # 예를 들어서 "I am a student." => "I am a student ."와 같이
    # student와 온점 사이에 거리를 만듭니다.
    sentence = re.sub(r"([?.!,])", r" \1 ", sentence)
    sentence = re.sub(r'[" "]+', " ", sentence)
    sentence = re.sub(r'\([^)]*\)', '', sentence) # 괄호로 닫힌 문자열 (...) 제거 Ex) my husband (and myself!) for => my husband for

    sentence = sentence.strip()
    return sentence

def preprocessing(data, features, corpus_file, max_samples = 40000):
    data.drop_duplicates(subset=features[0], inplace=True)
    if data.isnull().sum().sum() > 0:
        data.dropna(axis=0, inplace=True)
    for feature in features:
        data[feature] = data[feature].apply(preprocess_sentence)

    corpus_file = corpus_file
    with open(corpus_file, 'w', encoding='utf-8') as f:
        for q,a in zip(data[features[0]], data[features[1]]):
            f.write(q + "\n")
            f.write(a + "\n")
    if data.shape[0] < max_samples:
        return data[features]
    else:
        return data[features].iloc[:max_samples]

# %%
# dataset 정의
#========================================================================================================================================================================

class CustomDataset(Dataset):
    def __init__(self, data, sp, max_length=40, features=None, labels=None):
        super().__init__()
        self.sp = sp
        self.max_length = max_length * 2
        self.data = []

        if features is None:
            features = data.columns[:2]

        if labels is not None:          
            for q_text,a_text, label in zip(data[features[0]], data[features[1]], labels):
                # 1) tokenize
                q_ids = sp.EncodeAsIds(q_text)
                a_ids = sp.EncodeAsIds(a_text)
    
                # 2) <CLS>/<SEP> 같은 별도 스페셜 토큰을 사용하겠음
                # GPT) 입력이 1개 임으로 2 문장 전부 고려하려면 <sep> 과 같은 별도의 special token 사용해 모델이 Q와 A를 동시에 고려하게 할 생각
                #    여기서는 SentencePiece 기본 <s>, </s> 등 혹은 사용자 정의 토큰 활용 가능
                #    간단히 <s>=sp.bos_id(), </s>=sp.eos_id()로 가정해본다면:
                #    sp.SetEncodeExtraOptions("bos:eos") 등으로 설정하는 방법도 있음.
                # 여기서는 수동으로 bos/eos id를 붙인다고 가정
                bos_id = sp.bos_id() if sp.bos_id() >= 0 else 1
                eos_id = sp.eos_id() if sp.eos_id() >= 0 else 2
                sep_id = sp.PieceToId('<sep>') if sp.PieceToId('<sep>') >= 0 else 4
    
                token = [bos_id] + q_ids + [sep_id] + a_ids + [eos_id] + label
    
                # 3) 길이 제한
                if len(token) > self.max_length:
                    continue
                # 4) 고정 길이 패딩
                token += [0]*(self.max_length - len(token))  # 0 -> <pad> 가정

                # 5) 디코더 입력(dec_input): token, 타겟(outputs): a_tokens[1:]
                #    (teacher forcing용)
                dec_input = token
                target = token[1:]
        
                self.data.append({
                    "dec_input":token,
                    "target":target,
                })
        else:
            for q_text,a_text in zip(data[features[0]], data[features[1]]):
                # 1) tokenize
                q_ids = sp.EncodeAsIds(q_text)
                a_ids = sp.EncodeAsIds(a_text)
    
                # 2) <CLS>/<SEP> 같은 별도 스페셜 토큰을 사용하겠음
                # GPT) 입력이 1개 임으로 2 문장 전부 고려하려면 <sep> 과 같은 별도의 special token 사용해 모델이 Q와 A를 동시에 고려하게 할 생각
                #    여기서는 SentencePiece 기본 <s>, </s> 등 혹은 사용자 정의 토큰 활용 가능
                #    간단히 <s>=sp.bos_id(), </s>=sp.eos_id()로 가정해본다면:
                #    sp.SetEncodeExtraOptions("bos:eos") 등으로 설정하는 방법도 있음.
                # 여기서는 수동으로 bos/eos id를 붙인다고 가정
                bos_id = sp.bos_id() if sp.bos_id() >= 0 else 1
                eos_id = sp.eos_id() if sp.eos_id() >= 0 else 2
                sep_id = sp.PieceToId('<sep>') if sp.PieceToId('<sep>') >= 0 else 4
    
                token = [bos_id] + q_ids + [sep_id] + a_ids + [eos_id]
    
                # 3) 길이 제한
                if len(token) > self.max_length:
                    continue
                # 4) 고정 길이 패딩       
                token += [0]*(self.max_length - len(token))  # 0 -> <pad> 가정

                # 5) 디코더 입력(dec_input): token, 타겟(outputs): tokens[1:] + [0]
                # GPT) target과 길이 맞추기
                #    (teacher forcing용)
                dec_input = token
                target = token[1:] + [0]
        
                self.data.append({
                    "dec_input":token,
                    "target":target,
                })

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        sample = self.data[idx]
        # enc token 없음
        dec_input = torch.tensor(sample["dec_input"], dtype=torch.long)
        target = torch.tensor(sample["target"], dtype=torch.long)
        return dec_input, target

# %%
#Transformer model 설계
#============================================================================================================================================================================

def create_padding_mask(x):
    # x == 0 위치를 찾아 float형 1로 변환
    mask = (x==0).float()
    # (batch_size, seq_len) -> (batch_size, 1, 1, seq_len)
    mask = mask.unsqueeze(1).unsqueeze(2)
    return mask

def create_look_ahead_mask(x):
    seq_len = x.size(1)

    # (seq_len, seq_len) 크기의 하삼각 행렬(tril) 생성 후 1에서 빼서
    # 상삼각이 1, 하삼각(자기 자신 포함)이 0이 되도록 설정
    # => 미래 토큰(자신 인덱스보다 큰 위치) 마스킹
    look_ahead_mask = 1 - torch.tril(torch.ones((seq_len, seq_len)))

    # 패딩 마스크 생성 (shape: (batch_size, 1, 1, seq_len))
    padding_mask = create_padding_mask(x)

    # look_ahead_mask: (seq_len, seq_len) -> (1, seq_len, seq_len)  -> (1, 1, seq_len, seq_len)
    look_ahead_mask = look_ahead_mask.unsqueeze(0).unsqueeze(1)
    look_ahead_mask = look_ahead_mask.to(x.device)

    # look-ahead 마스크와 패딩 마스크를 합성 (둘 중 하나라도 1이면 마스킹)
    # 최종 shape은 브로드캐스팅으로 (batch_size, 1, seq_len, seq_len)
    combined_mask = torch.max(look_ahead_mask, padding_mask)
    return combined_mask

# Absolute positional encoding을 사용
class PositionalEncoding(nn.Module):
    def __init__(self, position, d_model):
        super(PositionalEncoding, self).__init__()
        self.d_model = d_model
        self.position = position

        self.pos_encoding = nn.Embedding(position+1, d_model)

    def forward(self, x):
        return self.pos_encoding(x).to(device)

def scaled_dot_product_attention(query, key, value, mask=None):
    
    # 1) Q와 K의 내적을 통해 score(유사도) 계산
    # key.transpose(-1, -2): (batch_size, heads, depth, seq_len)
    # matmul 결과 shape: (batch_size, heads, seq_len, seq_len)
    matmul_qk=torch.matmul(query, key.transpose(-1, -2))

    # 2) depth에 따라 정규화
    depth = key.size(-1) # depth = d_model / heads
    logits = matmul_qk / math.sqrt(depth)

    # 3) 마스크가 주어졌다면 -1e9(아주 작은 값)를 더해 소프트맥스에서 제외시키도록 함
    # 아주 작은 값이 더해지면 e^(logit+epsilon) 가 되기 때문에 e^logit * e^epsilon 이 되어 무시할 수 있는 값이 됨
    if mask is not None:
        logits = logits + (mask * -1e9)

    # 4) 소프트맥스 계산해 attention weights 생성
    attention_weights = F.softmax(logits, dim=-1)

    # 5) attention weights와 value의 내적
    output = torch.matmul(attention_weights, value)

    return output, attention_weights
    
class MultiHeadAttention(nn.Module):
    def __init__(self, d_model, num_heads, name="multi_head_attention"):
        super(MultiHeadAttention, self).__init__()
        self.num_heads = num_heads
        self.d_model = d_model

        # d_model은 num_heads로 나누어떨어져야 함
        assert d_model % num_heads == 0

        self.depth = d_model // num_heads

        # 파이토치에서 Dense는 nn.Linear로 대응
        self.query_dense = nn.Linear(d_model, d_model)
        self.key_dense = nn.Linear(d_model, d_model)
        self.value_dense = nn.Linear(d_model, d_model)

        self.out_dense = nn.Linear(d_model, d_model)

    def split_heads(self, x, batch_size):
        """
        x: (batch_size, seq_len, d_model)
        => (batch_size, num_heads, seq_len, depth) 형태로 변환
        """
        x = x.view(batch_size, -1, self.num_heads, self.depth)
        x = x.permute(0, 2, 1, 3)  # (batch_size, num_heads, seq_len, depth)
        return x

    def forward(self, query, key, value, mask=None):
        """
        query, key, value: (batch_size, seq_len, d_model)
        mask: (batch_size, 1, seq_len, seq_len) 등으로 broadcast 가능하도록 구성
        """
        batch_size = query.size(0)

        # Q, K, V에 각각 Linear 적용
        query = self.query_dense(query)
        key = self.key_dense(key)
        value = self.value_dense(value)

        # Head 분할
        query = self.split_heads(query, batch_size)
        key = self.split_heads(key, batch_size)
        value = self.split_heads(value, batch_size)

        # 스케일드 닷 프로덕트 어텐션
        scaled_attention, _ = scaled_dot_product_attention(query, key, value, mask)

        # (batch_size, num_heads, seq_len, depth) -> (batch_size, seq_len, num_heads, depth)
        scaled_attention = scaled_attention.permute(0, 2, 1, 3).contiguous()

        # 다시 (batch_size, seq_len, d_model)로 합치기
        concat_attention = scaled_attention.view(batch_size, -1, self.d_model)

        output = self.out_dense(concat_attention)
        return output


class DecoderLayer(nn.Module):
    def __init__(self, d_model, num_heads, ff_dim, dropout=0.1):
        super(DecoderLayer, self).__init__()

        # 첫 번째 서브 레이어 (디코더 내부 셀프 어텐션)
        # GPT) cross attention/ encoder-decoder attention 과정이 없음
        self.self_mha = MultiHeadAttention(d_model, num_heads)
        self.norm1 = nn.LayerNorm(d_model, eps=1e-6)

        #  번째 서브 레이어 (피드포워드 네트워크)
        self.ffn = nn.Sequential(
            nn.Linear(d_model, ff_dim),  # Dense(units=ff_dim)
            nn.ReLU(),                   # activation='relu'
            nn.Linear(ff_dim, d_model)   # Dense(units=d_model)
        )
        self.norm3 = nn.LayerNorm(d_model, eps=1e-6)

        # 드롭아웃
        self.dropout1 = nn.Dropout(dropout)
        self.dropout2 = nn.Dropout(dropout)
        self.dropout3 = nn.Dropout(dropout)

    def forward(self, x, look_ahead_mask=None, padding_mask=None):
        # 1) 셀프 어텐션 (디코더 내부)
        # GPT) cross attention/ encoder-decoder attention 과정이 없음
        self_attn_out = self.self_mha(x, x, x, mask=look_ahead_mask)
        self_attn_out = self.dropout1(self_attn_out)
        out1 = self.norm1(x + self_attn_out)  # 잔차 연결 + LayerNorm

        # 3) 피드포워드 (Dense -> ReLU -> Dense)
        ffn_out = self.ffn(out1)
        ffn_out = self.dropout3(ffn_out)
        out2 = self.norm3(out1 + ffn_out)  # 잔차 연결 + LayerNorm

        return out2

class Decoder(nn.Module):
    def __init__(self,
                 vocab_size,
                 num_layers,
                 ff_dim,
                 d_model,
                 num_heads,
                 dropout=0.1):
        super(Decoder, self).__init__()
        self.d_model = d_model

        # (1) 임베딩 레이어
        self.embedding = nn.Embedding(vocab_size, d_model)

        # (2) 포지셔널 인코딩
        # 실제 학습 시에는 최대 시퀀스 길이에 맞추어 쓰기도 함
        self.pos_encoding = PositionalEncoding(position=vocab_size, d_model=d_model)

        self.dropout = nn.Dropout(dropout)

        # (3) DecoderLayer 쌓기
        self.dec_layers = nn.ModuleList([
            DecoderLayer(d_model, num_heads, ff_dim, dropout) for _ in range(num_layers)
        ])

    def forward(self, x, look_ahead_mask=None, padding_mask=None):
        # (1) 임베딩 + sqrt(d_model)로 스케일링 + 포지셔널 인코딩 + 드롭아웃
        # GPT) 포지셔널 인코딩이 계산이 아닌 학습을 통해 구하도록 바뀜
        x = self.embedding(x) * math.sqrt(self.d_model) + self.pos_encoding(x) # (batch_size, tgt_seq_len, d_model)
        x = self.dropout(x)

        # (3) num_layers만큼 쌓인 DecoderLayer 통과
        for layer in self.dec_layers:
            x = layer(x, look_ahead_mask, padding_mask)

        return x

class Transformer(nn.Module):
    def __init__(self,
                 vocab_size,
                 num_layers,
                 units,
                 d_model,
                 num_heads,
                 dropout=0.1,
                label = None):

        super(Transformer, self).__init__()

        self.decoder = Decoder(
            vocab_size = vocab_size,
            num_layers = num_layers,
            ff_dim = units,
            d_model = d_model,
            num_heads = num_heads,
            dropout = dropout
        )

        # embedding 값 받기
        self.embedding = nn.Linear(d_model, vocab_size, bias=False)
        self.embedding.weight = self.decoder.embedding.weight

        # GPT) label 입력이 있는 supervised learning 일때만 구현
        if label==None:
            self.dropout = nn.Dropout(dropout)
            # 최종 출력층: (d_model) -> (vocab_size)
            self.final_linear = nn.Linear(d_model, vocab_size)

    # GPT) decoder input 만 받음
    def forward(self, dec_inputs, label=None):
        # GPT) encoder padding mask 없음

        # 2) 디코더 look-ahead + 패딩 마스크
        look_ahead_mask = create_look_ahead_mask(dec_inputs) # shape (batch_size, 1, tgt_seq_len, tgt_seq_len)

        # GPT) 디코더에서 인코더 출력 쪽을 마스킹할 때 쓸 패딩 마스크는 인코더 출력쪽을 받지 않기 때문에 필요 없음

        # 4) 디코더 수행
        # GPT) 인코더 없음/  인코더 output 받을 필요 없음
        dec_outputs = self.decoder(
            x = dec_inputs,                     # (batch_size, tgt_seq_len)
            look_ahead_mask = look_ahead_mask,
        ) # shape: (batch_size, tgt_seq_len, d_model)
        
        # GPT) label이 있으면 supervised learning 임으로 FFN 통과, 아니라면 embedding layer의 transpose를 곱해서 logit 연산
        if label is not None:
            logits = self.final_linear(self.dropout(dec_outputs)) # (batch_size, tgt_seq_len, vocab_size)
            logits_dec = self.embedding(dec_outputs)
            return logits, logits_dec
        else:
            logits = self.embedding(dec_outputs)
            return logits

# %%
# 시각화 및 보조 함수/ 기타
#=================================================================================================================================================================================

def Loss_Visualization(train_losses, val_losses):
    plt.plot(range(len(train_losses)), train_losses, 'b-',label='Train Loss')
    plt.plot(range(len(val_losses)), val_losses,'r--', label='Validation Loss')
    plt.legend()
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.title("Training and Validation Loss")
    plt.show()

def Acc_Visualization(train_acc, val_acc):
    plt.plot(range(len(train_acc)), train_acc, 'b-',label='Train Acc')
    plt.plot(range(len(val_acc)), val_acc,'r--', label='Validation Acc')
    plt.legend()
    plt.xlabel("Epochs")
    plt.ylabel("Acc")
    plt.title("Training and Validation Acc")
    plt.show()

def accuracy_function(y_pred, y_true, pad_id=0):
    """
    y_pred: (batch_size, seq_len, vocab_size)
    y_true: (batch_size, seq_len)
    """
    preds = y_pred.argmax(dim=-1)
    mask = (y_true != pad_id)
    correct = (preds == y_true) & mask
    acc = correct.float().sum() / mask.float().sum()
    return acc

def get_lr_lambda(d_model, warmup_steps = 4000):
    d_model = float(d_model)
    def lr_lambda(step):
        step += 1
        return (d_model ** -0.5) * min(step ** -0.5, step * (warmup_steps ** -1.5))

    return lr_lambda

# 학습 함수
#=======================================================================================================================================================================

def train_step(model, batch, optimizer, loss_function, device, _lambda):
    model.train()
    
    optimizer.zero_grad()

    if _lambda is None:
        # GPT) dec_input만 존재
        dec_input, target = [x.to(device) for x in batch]
        
        # 모델 포워드 패스
        logits = model(dec_input) # (batch_size, seq_len, vocab_size)
        
        # Loss 계산 (패딩 토큰 무시)
        loss = loss_function(logits.permute(0, 2, 1), target) # (batch_size, vocab_size, seq_len) 필요
    

    # GPT) lambda 가 있으면 loss가 2개 임으로 다음과 같이 계산
    else:
        dec_input, target, label = [x.to(device) for x in batch]
        
        # 모델 포워드 패스
        logits_2, logits_1 = model(dec_input, label) # (batch_size, seq_len, vocab_size)
        
        # Loss 계산 (패딩 토큰 무시)
        loss_2 = loss_function(logits_2.permute(0, 2, 1), target) # (batch_size, vocab_size, seq_len) 필요
        loss_1 = loss_function(logits_1.permute(0, 2, 1), target)

        loss = loss_2 + _lambda*loss_1
    
    # Backpropagation
    loss.backward()
    optimizer.step()

    return loss.item(), accuracy_function(logits, target, pad_id=sp.pad_id())

def eval_step(model, batch, loss_function, device, _lambda):
    model.eval()
    if _lambda is None:
        # GPT) dec_input만 존재
        dec_input, target = [x.to(device) for x in batch]
        
        # 모델 포워드 패스
        logits = model(dec_input) # (batch_size, seq_len, vocab_size)
        
        # Loss 계산 (패딩 토큰 무시)
        loss = loss_function(logits.permute(0, 2, 1), target) # (batch_size, vocab_size, seq_len) 필요
    

    # GPT) lambda 가 있으면 loss가 2개 임으로 다음과 같이 계산
    else:
        dec_input, target, label = [x.to(device) for x in batch]
        
        # 모델 포워드 패스
        logits_2, logits_1 = model(dec_input, label) # (batch_size, seq_len, vocab_size)
        
        # Loss 계산 (패딩 토큰 무시)
        loss_2 = loss_function(logits_2.permute(0, 2, 1), target) # (batch_size, vocab_size, seq_len) 필요
        loss_1 = loss_function(logits_1.permute(0, 2, 1), target)

        loss = loss_2 + _lambda*loss_1

    # Loss 계산 (패딩 토큰 무시)
    loss = loss_function(logits.permute(0, 2, 1), target) # (batch_size, vocab_size, seq_len) 필요

    return loss.item(), accuracy_function(logits, target, pad_id=sp.pad_id())

def train_model(model, train_dataset,vocab_size=8000, 
                num_layers=2, units=512, d_model=256,
                num_heads=8, dropout=0.1, train_ratio=0.8,
                warmup_steps=4000, criterion = 'CE', optimize='Adam',
                batch_size=256, epochs=50,lr = 0.001, 
                verbose = 1, patience=4, max_len = 40, _lambda = None):
    
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print(f"Using device: {device}")
    model = model(
        vocab_size=vocab_size,
        num_layers=NUM_LAYERS,
        units=UNITS,
        d_model=D_MODEL,
        num_heads=NUM_HEADS,
        dropout=DROPOUT
    )
    
    model.to(device)
    
    # 손실 함수 & 옵티마이저
    criterion = nn.CrossEntropyLoss(ignore_index=0)  # 패딩 토큰 무시
    
    if optimize=='AdamW':
        optimizer=optim.AdamW(model.parameters(), lr=lr)
    elif optimize=='Adam':
        optimizer=optim.Adam(model.parameters(), betas = (0.9, 0.98), eps=1e-9, lr=lr)
    elif optimze=="SGD":
        optimizer=optim.SGD(model.parameters(), lr=lr)
    else:
        optimizer=optim.Adam(model.parameters(), betas = (0.9, 0.98), eps=1e-9, lr=lr)

    scheduler = lr_scheduler.LambdaLR(optimizer, lr_lambda = get_lr_lambda(d_model, warmup_steps = 4000))

    train_losses = []
    val_losses = []
    train_acc_list = []
    val_acc_list = []

    train_size = int(len(train_dataset) * train_ratio)
    val_size = len(train_dataset) - train_size
    
    # 랜덤하게 dataset나누기
    tr_dataset, val_dataset = random_split(train_dataset, [train_size, val_size])
        
    model.train()
    best_param = dict()
    best_val_loss = float('inf')
    early_stop_counter = 0

    for epoch in range(epochs):
        total_loss, total_acc = 0, 0

        # PyTorch DataLoader 설정. epoch 마다 train과 test 에서   
        train_loader = DataLoader(tr_dataset, batch_size=batch_size, shuffle=True)
        val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

        for step, batch in enumerate(train_loader):
            optimizer.zero_grad()
            loss, acc = train_step(model, batch, optimizer, criterion, device, _lambda)
            total_loss += loss
            total_acc += acc

            if (step+1) % (verbose*100) == 0:
                print(f"[Epoch {epoch+1}, Step {step}] Loss: {loss:.4f}, Acc: {acc:.4f}")

            scheduler.step()

        avg_loss = total_loss / len(train_loader)
        avg_acc = total_acc / len(train_loader)
        train_losses.append(avg_loss)
        train_acc_list.append(avg_acc.to('cpu'))
        
        # Validation loss 계산
        model.eval()
        val_loss, val_acc = 0, 0
        with torch.no_grad():
            for batch in val_loader:
                loss, acc = eval_step(model, batch, criterion, device, _lambda)

                val_loss += loss
                val_acc += acc

        val_loss /= len(val_loader)
        val_losses.append(val_loss)
        val_acc /= len(val_loader)
        val_acc_list.append(val_acc.to('cpu'))
        
        if (epoch+1)%verbose==0:
            print(f"Epoch {epoch+1}/{epochs} | Train Loss: {avg_loss:.4f}, Train Acc: {avg_acc:.4f} | Val Loss: {val_loss:.4f}, Val Acc: {val_acc:.4f}")

        # Early Stopping 조건
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            best_param = copy.deepcopy(model.state_dict())
            early_stop_counter = 0
        else:
            early_stop_counter += 1

        if early_stop_counter >= patience:
            print(f"Early stopping triggered at epoch {epoch+1}")
            break

        model.train()

    model.load_state_dict(best_param)
        
    Loss_Visualization(train_losses, val_losses)
    Acc_Visualization(train_acc_list, val_acc_list)
    return model

# %%
# 추론 함수
# ==============================================================================================================================

def decoder_inference(model, sentence, tokenizer, device="cpu"):
    START_TOKEN = tokenizer.bos_id()
    END_TOKEN = tokenizer.eos_id()
    SEP_TOKEN = tokenizer.PieceToId('<sep>')
    MAX_LENGTH = 40
    
    # 전처리
    sentence = preprocess_sentence(sentence)

    # 인코더 입력: [START] + 인코딩 + [END]
    enc_input_ids = [START_TOKEN] + tokenizer.encode(sentence) + [END_TOKEN] + [SEP_TOKEN] + [START_TOKEN]

    length = len([START_TOKEN] + tokenizer.encode(sentence) + [END_TOKEN] + [SEP_TOKEN])

    # 차원 확장: (batch_size=1, seq_len)
    enc_input = torch.tensor([enc_input_ids], dtype=torch.long, device=device)


    model.eval()
    with torch.no_grad():
        for i in range(MAX_LENGTH):
            
            # 모델 forward: (enc_input) -> (batch_size=1, seq_len, vocab_size)
            # GPT) 추론시에도 
            logits = model(enc_input)

            # 마지막 타임스텝의 예측만 추출: shape (1, 1, vocab_size)
            # logits[:, -1, :] -> (1, vocab_size)
            last_step_logits = logits[:, -1, :]

            # argmax로 가장 높은 확률의 토큰 선택
            predicted_id = torch.argmax(last_step_logits, dim=-1)

            # 종료 토큰이면 중단
            if predicted_id.item() == END_TOKEN:
                break

            # 입력(enc_input)에 예측 토큰을 이어붙임
            predicted_id = predicted_id.unsqueeze(0) # shape (1,1)
            enc_input = torch.cat([enc_input, predicted_id], dim=1)

    # 최종 시퀀스: enc_input: (1, seq_len)에서 (seq_len,)로
    output_sequence = enc_input.squeeze(0).tolist() # e.g. [START_TOKEN, ..., 토큰들...]

    return output_sequence[length:]

def sentence_generation(model, sentence, tokenizer, device='cpu'):
    output_seq = decoder_inference(model, sentence, tokenizer, device=device)

    predicted_sentence = tokenizer.decode(
        [token for token in output_seq if token < tokenizer.GetPieceSize()]
    )
    print("입력 :", sentence)
    print("출력 :", predicted_sentence)
    return predicted_sentence

# %%
MAX_SAMPLES = 50000
corpus_file = "clean_corpus_project.txt"
data_preprocessing = preprocessing(data.copy(), features=["Q","A"], corpus_file= "clean_corpus_project.txt", max_samples = 50000)
data_preprocessing.sample(10)
# Out:
#                                        Q                         A
# 5778                 나라도 내 마음을 지켜야 하는 거야           본인 마음 좀 지켜주세요 .
# 1864                           미세먼지 나쁨인가             인터넷 검색 해보세요 .
# 10226  썸 타는 중인데 바빠서 연락 제대로 못하는데 이해해야겠지 .       좋아하는 마음이라면 이해해보세요 .
# 1397                            때려 치고 싶다           많이 지치고 힘든가봅니다 .
# 2341                            상사가 미울 때        사표를 써서 품에 품어 봅니다 .
# 11559             짝녀한테 크리스마스 선물로 뭐가 좋음 ?    많이 추우니 목도리는 어떨까 생각해요 .
# 3127                     에어 후라이어 사고 싶다 .  몇 번 안해먹고 둘 거면 그냥 사 드세요 .
# 11249                좋아하는 오빠랑 어떻게 친해질까 .    그분의 관심사에 대한 얘기가 좋겠어요 .
# 580                      나는 그냥저냥 사는 거 같아        오늘은 약간의 변화를 줘보세요 .
# 4794                          타이밍이 기가 막혀                 나이스 타이밍 !

# %%
data_preprocessing.shape
# Out:
# (11662, 2)

# %%
DataLengthVisualization(data_preprocessing,['Q', 'A'])
# Out:
# Q의 최소 길이 : 1
# Q의 최대 길이 : 16
# Q의 평균 길이 : 3.9477791116446577
# A의 최소 길이 : 1
# A의 최대 길이 : 24
# A의 평균 길이 : 4.720802606756989

# %%
# SentencePiece/ tokenization
        
spm.SentencePieceTrainer.Train(
    input = corpus_file,
    model_prefix="spm_cornell",
    vocab_size=8000,
    character_coverage=1.0,
    model_type="bpe",
    max_sentence_length = 999999,
    bos_id=1,  # <s> (Beginning of Sentence) 설정
    eos_id=2,  # </s> (End of Sentence) 설정
    pad_id=0,  # Padding ID 설정
    unk_id=3,   # Unknown Token ID 설정,
    user_defined_symbols = '<sep>'
)
sp = spm.SentencePieceProcessor()
sp.Load("spm_cornell.model")
# Out:
# sentencepiece_trainer.cc(78) LOG(INFO) Starts training with :
# trainer_spec {
#   input: clean_corpus_project.txt
#   input_format:
#   model_prefix: spm_cornell
#   model_type: BPE
#   vocab_size: 8000
#   self_test_sample_size: 0
#   character_coverage: 1
#   input_sentence_size: 0
#   shuffle_input_sentence: 1
#   seed_sentencepiece_size: 1000000
#   shrinking_factor: 0.75
#   max_sentence_length: 999999
#   num_threads: 16
#   num_sub_iterations: 2
#   max_sentencepiece_length: 16
#   split_by_unicode_script: 1
#   split_by_number: 1
#   split_by_whitespace: 1
#   split_digits: 0
#   pretokenization_delimiter:
#   treat_whitespace_as_suffix: 0
#   allow_whitespace_only_pieces: 0
#   user_defined_symbols: <sep>
#   required_chars:
#   byte_fallback: 0
#   vocabulary_output_piece_score: 1
#   train_extremely_large_corpus: 0
#   seed_sentencepieces_file:
#   hard_vocab_limit: 1
#   use_all_vocab: 0
#   unk_id: 3
#   bos_id: 1
#   eos_id: 2
#   pad_id: 0
#   unk_piece: <unk>
#   bos_piece: <s>
#   eos_piece: </s>
#   pad_piece: <pad>
#   unk_surface:  ⁇
#   enable_differential_privacy: 0
#   differential_privacy_noise_level: 0
#   differential_privacy_clipping_threshold: 0
# }
# normalizer_spec {
#   name: nmt_nfkc
#   add_dummy_prefix: 1
#   remove_extra_whitespaces: 1
#   escape_whitespaces: 1
#   normalization_rule_tsv:
# }
# denormalizer_spec {}
# trainer_interface.cc(355) LOG(INFO) SentenceIterator is not specified. Using MultiFileSentenceIterator.
# trainer_interface.cc(186) LOG(INFO) Loading corpus: clean_corpus_project.txt
# trainer_interface.cc(411) LOG(INFO) Loaded all 23324 sentences
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <pad>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <s>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: </s>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <unk>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <sep>
# trainer_interface.cc(432) LOG(INFO) Normalizing sentences...
# trainer_interface.cc(541) LOG(INFO) all chars count=365250
# trainer_interface.cc(562) LOG(INFO) Alphabet size=1236
# trainer_interface.cc(563) LOG(INFO) Final character coverage=1
# trainer_interface.cc(594) LOG(INFO) Done! preprocessed 23324 sentences.
# trainer_interface.cc(600) LOG(INFO) Tokenizing input sentences with whitespace: 23324
# trainer_interface.cc(611) LOG(INFO) Done! 20678
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=13780 min_freq=42
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1046 size=20 all=16589 active=1771 piece=▁거예요
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=764 size=40 all=17331 active=2513 piece=봐요
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=609 size=60 all=17992 active=3174 piece=▁좋아하는
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=423 size=80 all=18599 active=3781 piece=▁모
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=355 size=100 all=19327 active=4509 piece=▁주
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=355 min_freq=37
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=303 size=120 all=19766 active=1398 piece=▁뭐
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=261 size=140 all=20390 active=2022 piece=▁이제
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=224 size=160 all=20789 active=2421 piece=게요
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=203 size=180 all=21140 active=2772 piece=▁행
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=187 size=200 all=21521 active=3153 piece=▁다시
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=185 min_freq=30
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=168 size=220 all=21878 active=1428 piece=▁싫
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=153 size=240 all=22207 active=1757 piece=▁조금
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=142 size=260 all=22513 active=2063 piece=▁반
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=134 size=280 all=22910 active=2460 piece=▁짝녀
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=129 size=300 all=23211 active=2761 piece=▁바랄게요
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=128 min_freq=26
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=120 size=320 all=23575 active=1525 piece=▁동
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=114 size=340 all=23957 active=1907 piece=▁아닌
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=107 size=360 all=24183 active=2133 piece=▁돈
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=103 size=380 all=24526 active=2476 piece=▁않아요
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=98 size=400 all=24877 active=2827 piece=▁바랍니다
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=97 min_freq=22
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=91 size=420 all=25155 active=1522 piece=▁상처
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=86 size=440 all=25386 active=1753 piece=다가
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=83 size=460 all=25604 active=1971 piece=▁2
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=80 size=480 all=25871 active=2238 piece=▁머리
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=77 size=500 all=26123 active=2490 piece=▁이유
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=77 min_freq=19
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=74 size=520 all=26370 active=1543 piece=▁어떨까요
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=71 size=540 all=26619 active=1792 piece=▁스트레
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=67 size=560 all=26860 active=2033 piece=았는데
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=65 size=580 all=27046 active=2219 piece=▁인연
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=63 size=600 all=27213 active=2386 piece=▁갈
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=63 min_freq=17
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=61 size=620 all=27397 active=1531 piece=▁노래
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=59 size=640 all=27669 active=1803 piece=기를
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=57 size=660 all=27942 active=2076 piece=스럽
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=55 size=680 all=28130 active=2264 piece=▁가보세요
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=53 size=700 all=28236 active=2370 piece=▁영화
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=53 min_freq=15
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=51 size=720 all=28403 active=1568 piece=▁언젠
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=50 size=740 all=28531 active=1696 piece=▁아침
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=49 size=760 all=28654 active=1819 piece=▁상대방
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=47 size=780 all=28808 active=1973 piece=▁울
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=46 size=800 all=28982 active=2147 piece=▁키
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq

# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6360 all=37674 active=1835 piece=▁보다보면
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6380 all=37661 active=1822 piece=▁샌드위치
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6400 all=37646 active=1807 piece=▁신고하고
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=4 min_freq=3
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6420 all=37629 active=1866 piece=▁없답니다
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6440 all=37613 active=1850 piece=▁이름이랑
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6460 all=37599 active=1836 piece=▁있으니까
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6480 all=37582 active=1819 piece=▁집에서도
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6500 all=37567 active=1804 piece=▁하니까요
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=4 min_freq=3
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6520 all=37548 active=1860 piece=▁힘들겠죠
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6540 all=37542 active=1854 piece=▁끝났습니다
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6560 all=37522 active=1834 piece=▁따뜻해졌죠
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6580 all=37502 active=1814 piece=▁선택이었을
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6600 all=37483 active=1795 piece=▁연락이라도
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=4 min_freq=3
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6620 all=37464 active=1856 piece=▁정정기간을
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6640 all=37449 active=1841 piece=▁흘려보세요
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6660 all=37429 active=1821 piece=▁절약되겠네요
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3 size=6680 all=37416 active=1808 piece=▁깍
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3 size=6700 all=37431 active=1823 piece=▁박
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=3 min_freq=3
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3 size=6720 all=37444 active=1883 piece=▁쭉
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3 size=6740 all=37460 active=1899 piece=간질
# trainer_interface.cc(689) LOG(INFO) Saving model: spm_cornell.model
# trainer_interface.cc(701) LOG(INFO) Saving vocabs: spm_cornell.vocab

# %%
# max_len 정하기
MAX_LEN = 8

# %%
#dataset 생성
dataset = CustomDataset(data_preprocessing, sp, max_length=MAX_LEN, features = ['Q', 'A'])

# %%
# 예: 하이퍼파라미터 설정
NUM_LAYERS = 8                   # 인코더/디코더 층 수
D_MODEL = 512                    # 임베딩 및 내부 표현 차원
NUM_HEADS = 8                    # 멀티헤드 어텐션에서의 헤드 수
UNITS = 2048                     # 피드포워드 신경망의 은닉 차원
DROPOUT = 0.1                    # 드롭아웃 비율
VOCAB_SIZE = sp.get_piece_size() # 단어 집합 크기(예시)
WARMUP_STEPS = 3000
BATCH_SIZE = 256
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
print(len(dataset))
# Out:
# 8904

# %%
# 모델 학습
model = train_model(Transformer, dataset, vocab_size=VOCAB_SIZE, 
                num_layers=NUM_LAYERS, units=UNITS, d_model=D_MODEL,
                num_heads=NUM_HEADS, dropout=DROPOUT, warmup_steps=WARMUP_STEPS, 
                batch_size=BATCH_SIZE, epochs=50,lr = 0.001, verbose = 1, train_ratio=0.9)
# Out:
# Using device: cuda
# Epoch 1/50 | Train Loss: 306.2958, Train Acc: 0.0011 | Val Loss: 336.7572, Val Acc: 0.0009
# Epoch 2/50 | Train Loss: 305.9244, Train Acc: 0.0010 | Val Loss: 336.3782, Val Acc: 0.0009
# Epoch 3/50 | Train Loss: 305.6348, Train Acc: 0.0010 | Val Loss: 335.7495, Val Acc: 0.0009
# Epoch 4/50 | Train Loss: 304.9167, Train Acc: 0.0010 | Val Loss: 334.8626, Val Acc: 0.0009
# Epoch 5/50 | Train Loss: 304.0440, Train Acc: 0.0010 | Val Loss: 333.7154, Val Acc: 0.0009
# Epoch 6/50 | Train Loss: 302.9035, Train Acc: 0.0010 | Val Loss: 332.2972, Val Acc: 0.0009
# Epoch 7/50 | Train Loss: 301.5515, Train Acc: 0.0010 | Val Loss: 330.6015, Val Acc: 0.0009
# Epoch 8/50 | Train Loss: 300.0544, Train Acc: 0.0010 | Val Loss: 328.6168, Val Acc: 0.0009
# Epoch 35/50 | Train Loss: 153.2470, Train Acc: 0.0010 | Val Loss: 160.3910, Val Acc: 0.0009
# Epoch 36/50 | Train Loss: 146.1741, Train Acc: 0.0011 | Val Loss: 152.6785, Val Acc: 0.0009
# Epoch 37/50 | Train Loss: 139.0343, Train Acc: 0.0010 | Val Loss: 145.0628, Val Acc: 0.0009
# Epoch 38/50 | Train Loss: 132.1176, Train Acc: 0.0010 | Val Loss: 137.5819, Val Acc: 0.0009
# Epoch 39/50 | Train Loss: 125.3048, Train Acc: 0.0011 | Val Loss: 130.2552, Val Acc: 0.0009
# Epoch 40/50 | Train Loss: 118.6411, Train Acc: 0.0010 | Val Loss: 123.1318, Val Acc: 0.0009
# Epoch 41/50 | Train Loss: 112.2560, Train Acc: 0.0010 | Val Loss: 116.2318, Val Acc: 0.0008
# Epoch 42/50 | Train Loss: 105.9760, Train Acc: 0.0010 | Val Loss: 109.5948, Val Acc: 0.0008
# Epoch 43/50 | Train Loss: 100.1563, Train Acc: 0.0010 | Val Loss: 103.2510, Val Acc: 0.0008
# Epoch 44/50 | Train Loss: 94.5704, Train Acc: 0.0010 | Val Loss: 97.2665, Val Acc: 0.0008
# Epoch 45/50 | Train Loss: 89.4933, Train Acc: 0.0011 | Val Loss: 91.6929, Val Acc: 0.0009
# Epoch 46/50 | Train Loss: 84.8152, Train Acc: 0.0012 | Val Loss: 86.5998, Val Acc: 0.0010
# Epoch 47/50 | Train Loss: 80.7667, Train Acc: 0.0013 | Val Loss: 82.0555, Val Acc: 0.0013
# Epoch 48/50 | Train Loss: 77.1391, Train Acc: 0.0015 | Val Loss: 77.9834, Val Acc: 0.0014
# Epoch 49/50 | Train Loss: 73.9370, Train Acc: 0.0018 | Val Loss: 74.3313, Val Acc: 0.0016
# Epoch 50/50 | Train Loss: 71.0654, Train Acc: 0.0020 | Val Loss: 71.0208, Val Acc: 0.0017

# %%
# 데이터 내 문장 (짧은 문장)
sentence = '놀고 싶다.'
sentence_generation(model, sentence, sp, device)
# Out:
# 입력 : 놀고 싶다.
# 출력 : 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴
# '그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴'

# %%
# 데이터 내 문장 (긴 문장)
sentence = '썸을 오래 탔는데 사귀어도 괜찮은 사람일까?'
sentence_generation(model, sentence, sp, device)
# Out:
# 입력 : 썸을 오래 탔는데 사귀어도 괜찮은 사람일까?
# 출력 : . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# '. . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .'

# %%
# 데이터 내 문장 2개 합성
sentence = '내 여자친구 아이돌이야. 여자친구가 너무 예뻐'
sentence_generation(model, sentence, sp, device)
# Out:
# 입력 : 내 여자친구 아이돌이야. 여자친구가 너무 예뻐
# 출력 : 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁
# '킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁'

# %%
# 데이터 내 문장 단어 대체
sentence = '사과 먹고 싶다.'
sentence_generation(model, sentence, sp, device)
# Out:
# 입력 : 사과 먹고 싶다.
# 출력 : 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁
# '킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁 킁'

# %%
# 데이터 외 문장
sentence = '인공지능이 흥미로워'
sentence_generation(model, sentence, sp, device)
# Out:
# 입력 : 인공지능이 흥미로워
# 출력 : 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴
# '그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴 그럴'
